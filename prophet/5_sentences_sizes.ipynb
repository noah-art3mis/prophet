# %%
import pathlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from book_registry import books

df = pd.read_feather("../data/preprocessing/book-5_chunked88_withprev.feather")
df
# Out:
#         book  sentence  chapter  sentence_chapter  \
# 0     book-5         1        1                 1
# 1     book-5         2        1                 2
# 2     book-5         3        1                 3
# 3     book-5         4        1                 4
# 4     book-5         5        1                 5
# ...      ...       ...      ...               ...
# 3755  book-5      3756       28               118
# 3756  book-5      3757       28               119
# 3757  book-5      3758       28               120
# 3758  book-5      3759       28               121
# 3759  book-5      3760       28               122
#
#                                                 content  \
# 0     This year we have taken the formations of the ...
# 1     Those of you - I think it was the majority - w...
# 2     A certain number of you - I am only expressing...
# 3     Those who have had the courage to do so will b...
# 4     In a way it is a modest enough ambition for me...
# ...

# %% [markdown]
# ### Sampling

# %%
sample_50 = df.sample(n=50, random_state=42)
sample_50.head()
# Out:
#         book  sentence  chapter  sentence_chapter  \
# 1553  book-5      1554       12                14
# 2986  book-5      2987       23                46
# 220   book-5       221        2                83
# 2965  book-5      2966       23                25
# 1971  book-5      1972       15                34
#
#                                                 content  \
# 1553  Abundantly expressed by all the authors, this ...
# 2986  The presence, the predominance of what is, whe...
# 220   At first sight forgetting is not the same thin...
# 2965  It is the point from which she identifies hers...
# 1971  It is for this reason that there are three pol...
#
#                                       previous_sentence
# 1553  He thinks he has to put aside all its structur...
# 2986  This phantasy is of course far from being limi...
# 220   Just as we have spoken about maritablement , l...
# 2965  Dora identifies herself with Mr. K. The woman ...
# ...

# %%
sample_500 = df.sample(n=500, random_state=42)
sample_500
# Out:
#         book  sentence  chapter  sentence_chapter  \
# 1553  book-5      1554       12                14
# 2986  book-5      2987       23                46
# 220   book-5       221        2                83
# 2965  book-5      2966       23                25
# 1971  book-5      1972       15                34
# ...      ...       ...      ...               ...
# 3752  book-5      3753       28               115
# 214   book-5       215        2                77
# 2464  book-5      2465       19                21
# 2603  book-5      2604       20                58
# 157   book-5       158        2                20
#
#                                                 content  \
# 1553  Abundantly expressed by all the authors, this ...
# 2986  The presence, the predominance of what is, whe...
# 220   At first sight forgetting is not the same thin...
# 2965  It is the point from which she identifies hers...
# 1971  It is for this reason that there are three pol...
# ...

# %%
# sample_50.to_csv("../data/preprocessing/book-5_chunked88_withprev_sample50.csv")
# sample_500.to_csv("../data/preprocessing/book-5_chunked88_withprev_sample500.csv")
# df.to_csv("../data/preprocessing/book-5_chunked88_withprev_nosample.csv")
